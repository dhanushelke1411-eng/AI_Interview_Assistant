# %%
# !pip install transformers torch gradio

# %%
from transformers import pipeline

interviewer = pipeline(
    "text-generation",
    model="gpt2"
)

print("AI Interview Assistant Ready")
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# AI Interview Assistant Ready

# %%
job_role = input("Enter Job Role: ")

prompt = f"Generate 5 interview questions for a {job_role} position."

response = interviewer(
    prompt,
    max_length=120,
    num_return_sequences=1
)

print("\nInterview Questions:\n")
print(response[0]['generated_text'])
# Out:
# Enter Job Role: Machine Learning Engineer
# Passing `generation_config` together with generation-related arguments=({'max_length', 'num_return_sequences'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=120) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Interview Questions:
#
# Generate 5 interview questions for a Machine Learning Engineer position.
#
# Firing Date: July 12, 2018
#
# Location: Houston, Texas
#
# Job Type: Software Engineer
#
# Salary: $80,000 per year
#
# Required experience: Machine Learning
#
# Description: I am a Software Engineer with a background in the use of machine learning. I am interested in developing and testing automation solutions for businesses, IT systems, and organizations.
#
# I would like to have a chance to demonstrate the concept of machine learning. I would like to work with a team that is familiar with using machine learning and is interested in developing automation solutions for businesses, IT systems, and organizations.
#
# Subject: Machine Learning, Machine Learning, and the Future of AI
#
# We have been working on a new job application. Would you like to learn about why machine learning in AI is important and why applying for a new job?
#
# Firing Date: September 30, 2018
#
# Location: San Francisco, California
#
# Job Type: Software Engineer
#
# Salary: $65,000 per year
#
# Required experience: Machine Learning
#
# Description: I am an experienced Software Engineer with a background in machine learning and a passion for machine learning. I would like to work with a team that knows the fundamentals of machine learning

# %%
job_role = input("Enter Job Role: ")

prompt = f"""
You are an AI Interview Coach.

Generate:
1. 5 interview questions
2. Short sample answers
3. Interview tips

for a {job_role} position.
"""

response = interviewer(
    prompt,
    max_length=300,
    num_return_sequences=1
)

print("\nAI Interview Preparation:\n")
print(response[0]['generated_text'])
# Out:
# Enter Job Role: Data Analyst
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=300) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# AI Interview Preparation:
#
#
# You are an AI Interview Coach.
#
# Generate:
# 1. 5 interview questions
# 2. Short sample answers
# 3. Interview tips
#
# for a Data Analyst position.
#
# 1. Interview questions
#
# 2. Short sample answers
#
# 3. Interview tips
#
# for a Data Analyst position.
#
# The interviewer is the main person who will ask the questions. The interviewer is the person who will ask the questions.
#
# 1. Interview questions
#
# 2. Short sample answers
#
# 3. Interview tips
#
# for a Data Analyst position.
#
# The interviewer is the person who will ask the questions.
#
# 1. Interview questions
#
# 2. Short sample answers
#
# 3. Interview tips
#
# for a Data Analyst position.
#
# The interviewer is the person who will ask the questions.
#
# 1. Interview questions
#
# 2. Short sample answers
#
# 3. Interview tips
#
# for a Data Analyst position.
#
# The interviewer is the person who will ask the questions.
#
# 1. Interview questions
#
# 2. Short sample answers
#
# 3. Interview tips
#
# for a Data Analyst position.
#
# The interviewer is the person who will ask the questions.
#
# 1. Interview questions
#
# 2. Short sample answers
#
# 3. Interview tips
#
# for a Data Analyst position.
#
# The interviewer is the person who will ask the questions.
#
# 1. Interview
